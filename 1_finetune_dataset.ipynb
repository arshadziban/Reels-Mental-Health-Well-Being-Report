# %%
import os
import pandas as pd
from dotenv import load_dotenv
from gsheet_loader import load_sheet
load_dotenv()
# Out:
# True

# %%
# Load a Google Sheet
url = os.environ["GOOGLE_SHEET_URL"]
data = load_sheet(url)
df = pd.read_csv(data)
df.head()
# Out:
#             Timestamp A1. Your age (আপনার বয়স) A2. You are (আপনি )  \
# 0  12/15/2025 0:37:42                        24          Male(ছেলে)
# 1  12/15/2025 0:51:14                        28          Male(ছেলে)
# 2  12/15/2025 0:54:55                        25        Female(মেয়ে)
# 3  12/15/2025 1:01:26                        25          Male(ছেলে)
# 4  12/15/2025 1:13:01                        25        Female(মেয়ে)
#
#   A3. Your religion(আপনার ধর্ম) A4. Your marital status(আপনার বৈবাহিক অবস্থা)  \
# 0                 Islam (ইসলাম)                             Married (বিবাহিত)
# 1                 Islam (ইসলাম)                          Unmarried (অবিবাহিত)
# 2                 Islam (ইসলাম)                          Unmarried (অবিবাহিত)
# 3                 Islam (ইসলাম)                             Married (বিবাহিত)
# 4                 Islam (ইসলাম)                          Unmarried (অবিবাহিত)
#
#   A5. Where do you live?(আপনি কোথায় বসবাস করেন ?)  \
# 0                        Urban Area (শহুরে এলাকা)
# 1                        Urban Area (শহুরে এলাকা)
# 2                        Urban Area (শহুরে এলাকা)
# 3                        Urban Area (শহুরে এলাকা)
# 4                        Urban Area (শহুরে এলাকা)
#
#           A6. Occupation(পেশা)  \
# 0          Student (স্টুডেন্ট)
# 1  Service Holder (চাকুরীজীবী)
# 2          Student (স্টুডেন্ট)
# 3          Student (স্টুডেন্ট)
# 4          Student (স্টুডেন্ট)
#
#   B1. What kind of family do you live in?(আপনি কি ধরনের পরিবারে বসবাস করেন?)  \
# 0                         Single family(একক পরিবার )
# 1                          Joint Family (যৌথ পরিবার)
# 2                         Single family(একক পরিবার )
# 3                          Joint Family (যৌথ পরিবার)
# 4                         Single family(একক পরিবার )
#
#   B2. How much time do you typically spend with your family each day? (আপনি প্রতিদিন সাধারণ কত সময় আপনার পরিবারের সাথে কাটান?)\n____________ Hours(ঘন্টা)  \
# 0                                                  3
# 1                                         10 min max
# 2                                                5/6
# 3                                          2/3 Hours
# 4                                                  0
#
#   B3. How is your relationship with your family?(আপনার পরিবারের সাথে আপনার সম্পর্ক কেমন?)\n  \
# 0                                        Good (ভালো)
# 1                              Very Good (খুবই ভালো)
# 2                              Very Good (খুবই ভালো)
# 3                                  Moderate (মাঝারি)
# 4                                        Good (ভালো)
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   G6. Do you sometimes or often experience panic attacks(racing heartbeat, shortness of breath?) (আপনি কি কখনো আতঙ্ক বা প্যানিক অ্যাটাক(দ্রুত হৃদস্পন্দন, শ্বাসকষ্ট) অনুভব করেন?)  \
# 0                              Sometimes (মাঝে মাঝে)
# 1                                    Never (কখনো না)
# 2                              Sometimes (মাঝে মাঝে)
# 3                                    Never (কখনো না)
# 4                              Sometimes (মাঝে মাঝে)
#
#   G7.What type are you according to your behavior?(আপনার আচরণ অনুযায়ী আপনি কোন ধরণের?)  \
# 0                              Extrovert (বহির্মুখী)
# 1                             Introvert (অন্তর্মুখী)
# 2                             Introvert (অন্তর্মুখী)
# 3                                Ambivert (মাঝামাঝি)
# 4                                Ambivert (মাঝামাঝি)
#
#   G8.Do you watch reels because of an addiction, even if you don't have the desire to watch them? (আপনার রিলস দেখার ইচ্ছা না থাকলেও আসক্তির কারণে আপনি কি  রিলস দেখেন?)   \
# 0                              Sometimes (মাঝে মাঝে)
# 1                                    Never (কখনো না)
# 2                                    Always (সবসময়)
# 3                              Sometimes (মাঝে মাঝে)
# 4                                    Always (সবসময়)
#
#   H1. Does your mental state change after watching Facebook viral reels?(ফেসবুক এ ভাইরাল রিলস দেখার পরে কি আপনার মানসিক অবস্থার পরিবর্তন হয়?)  \
# 0                   Some Change (কিছুটা পরিবর্তন হয়)
# 1                           No Change (পরিবর্তন নেই)
# 2                   Some Change (কিছুটা পরিবর্তন হয়)
# 3                   Some Change (কিছুটা পরিবর্তন হয়)
# 4                   Some Change (কিছুটা পরিবর্তন হয়)
#
#   H2. Does watching tragic or entertaining content on Facebook Reels have any effect on your mental state (excitement, enthusiasm,anxiety)?(ফেসবুক রিলস এ মর্মান্তিক বা বিনোদনমূলক বিষয়বস্তু দেখলে সেটা কি আপনার মানসিক অবস্থার (যেমন: উত্তেজনা,উদ্দীপনা, উদ্বেগ) উপর কোনো  প্রভাব ফেলে?)\n  \
# 0                  Negative Impact (নেতিবাচক প্রভাব)
# 1                     No Impact (কোনো প্রভাব পড়ে না)
# 2                              Not Sure (নিশ্চিত না)
# 3                              Not Sure (নিশ্চিত না)
# 4                              Not Sure (নিশ্চিত না)
#
#   H3. Do you become distracted or inattentive after watching viral reels on Facebook?(ফেসবুক এ ভাইরাল রিলস দেখার পর আপনি কি বিভ্রান্ত বা অমনোযোগী হয়ে যান?)  \
# 0                              Sometimes (মাঝে মাঝে)
# 1                                    Never (কখনো না)
# 2                              Sometimes (মাঝে মাঝে)
# 3                                    Never (কখনো না)
# 4                                    Rarely (খুব কম)
#
#   H4. Does your brain feel extra pressure after watching viral content?(ভাইরাল কনটেন্ট দেখার পর কি আপনার মস্তিষ্কে অতিরিক্ত চাপ অনুভব হয়?)  \
# 0              Moderate Stress (মাঝারি চাপ অনুভব হয়)
# 1                        No Stress (চাপ অনুভব হয় না)
# 2                        No Stress (চাপ অনুভব হয় না)
# 3                        No Stress (চাপ অনুভব হয় না)
# 4                  Low Stress (সামান্য চাপ অনুভব হয়)
#
#   H5. Does watching viral reels on Facebook before bed change your sleep quality?(ঘুমানোর আগে ফেসবুকে ভাইরাল রিলস দেখার কারণে কি আপনার ঘুমের মানের কোনো পরিবর্তন হয়?)  \
# 0  Slight Change in Sleep Quality (ঘুমের মান কিছু...
# 1                              Not Sure (নিশ্চিত না)
# 2                              Not Sure (নিশ্চিত না)
# 3                              Not Sure (নিশ্চিত না)
# 4  Slight Change in Sleep Quality (ঘুমের মান কিছু...
#
#   H6. Does watching emotional reels make you lose focus on studies or work?(আবেগপ্রবণ রিলস  দেখার পর কি আপনার পড়াশোনা বা কাজের প্রতি মনোযোগ কমে যায়?)  \
# 0       Lose Focus Frequently (অত্যধিক মনোযোগ হারায়)
# 1                  Do Not Lose Focus (মনোযোগ কমে না)
# 2      Lose Focus Sometimes (মাঝে মাঝে মনোযোগ হারায়)
# 3                  Do Not Lose Focus (মনোযোগ কমে না)
# 4            Lose Focus Rarely (খুব কম মনোযোগ হারায়)
#
#   H7. When a viral reel sparks excitement or curiosity in you, do you feel inclined to watch more reels related to that?(যখন কোনো ভাইরাল রিলস আপনার মধ্যে উত্তেজনা বা কৌতূহল জাগিয়ে তোলে, তখন কি আপনি সেই সম্পর্কিত আরও রিলস দেখার জন্য আগ্রহী হন?)
# 0          Sometimes Interested (মাঝে মাঝে আগ্রহ হয়)
# 1                Rarely Interested (খুব কম আগ্রহ হয়)
# 2  More Interest in Watching Reels (আরও রিলস দেখা...
# 3          Sometimes Interested (মাঝে মাঝে আগ্রহ হয়)
# 4          Sometimes Interested (মাঝে মাঝে আগ্রহ হয়)
#
# [5 rows x 42 columns]

# %%
# Rename columns to short, code-based names (e.g. A1_age, A2_gender, ...)
import re

# Human-readable label for each question code (based on the English question text)
code_labels = {
    "A1": "age",
    "A2": "gender",
    "A3": "religion",
    "A4": "marital_status",
    "A5": "residence",
    "A6": "occupation",
    "B1": "family_type",
    "B2": "family_time_hours",
    "B3": "family_relationship",
    "B4": "in_person_feeling",
    "C1": "height",
    "C2": "weight",
    "C3": "sitting_duration",
    "C4": "physical_problems",
    "D1": "years_watching",
    "D2": "daily_watch_time",
    "D3": "peak_watch_time",
    "D4": "multitasking_while_watching",
    "E1": "sleep_hours",
    "E2": "sleep_trouble",
    "E3": "exercise_involvement",
    "E4": "substance_use",
    "F1": "attention_decreased",
    "F2": "memory_reduced",
    "F3": "learning_interest_decreased",
    "F4": "performance_affected",
    "G1": "mood_swings",
    "G2": "fomo_anxiety",
    "G3": "social_comparison",
    "G4": "social_isolation",
    "G5": "mental_stress",
    "G6": "panic_attacks",
    "G7": "behavior_type",
    "G8": "addictive_watching",
    "H1": "mental_state_change",
    "H2": "content_type_effect",
    "H3": "distraction_after_viral",
    "H4": "brain_pressure",
    "H5": "sleep_quality_change",
    "H6": "emotional_reels_focus_loss",
    "H7": "curiosity_driven_rewatch",
}

code_pattern = re.compile(r"^\s*([A-H]\d{1,2})\s*[.)]")


def clean_column_name(col: str) -> str:
    if col.strip().lower() == "timestamp":
        return "timestamp"
    match = code_pattern.match(col)
    if match:
        code = match.group(1)
        label = code_labels.get(code)
        if label:
            return f"{code}_{label}"
    return col


df = df.rename(columns=clean_column_name)
df = df.drop(columns=["timestamp"])
df.columns.tolist()
# Out:
# ['A1_age',
#  'A2_gender',
#  'A3_religion',
#  'A4_marital_status',
#  'A5_residence',
#  'A6_occupation',
#  'B1_family_type',
#  'B2_family_time_hours',
#  'B3_family_relationship',
#  'B4_in_person_feeling',
#  'C1_height',
#  'C2_weight',
#  'C3_sitting_duration',
#  'C4_physical_problems',
#  'D1_years_watching',
#  'D2_daily_watch_time',
#  'D3_peak_watch_time',
#  'D4_multitasking_while_watching',
#  'E1_sleep_hours',
#  'E2_sleep_trouble',
#  'E3_exercise_involvement',
#  'E4_substance_use',
#  'F1_attention_decreased',
#  'F2_memory_reduced',
#  'F3_learning_interest_decreased',
#  'F4_performance_affected',
#  'G1_mood_swings',
#  'G2_fomo_anxiety',
#  'G3_social_comparison',
#  'G4_social_isolation',
#  'G5_mental_stress',
#  'G6_panic_attacks',
#  'G7_behavior_type',
#  'G8_addictive_watching',
#  'H1_mental_state_change',
#  'H2_content_type_effect',
#  'H3_distraction_after_viral',
#  'H4_brain_pressure',
#  'H5_sleep_quality_change',
#  'H6_emotional_reels_focus_loss',
#  'H7_curiosity_driven_rewatch']

# %%
df.head()
# Out:
#   A1_age     A2_gender    A3_religion     A4_marital_status  \
# 0     24    Male(ছেলে)  Islam (ইসলাম)     Married (বিবাহিত)
# 1     28    Male(ছেলে)  Islam (ইসলাম)  Unmarried (অবিবাহিত)
# 2     25  Female(মেয়ে)  Islam (ইসলাম)  Unmarried (অবিবাহিত)
# 3     25    Male(ছেলে)  Islam (ইসলাম)     Married (বিবাহিত)
# 4     25  Female(মেয়ে)  Islam (ইসলাম)  Unmarried (অবিবাহিত)
#
#                A5_residence                A6_occupation  \
# 0  Urban Area (শহুরে এলাকা)          Student (স্টুডেন্ট)
# 1  Urban Area (শহুরে এলাকা)  Service Holder (চাকুরীজীবী)
# 2  Urban Area (শহুরে এলাকা)          Student (স্টুডেন্ট)
# 3  Urban Area (শহুরে এলাকা)          Student (স্টুডেন্ট)
# 4  Urban Area (শহুরে এলাকা)          Student (স্টুডেন্ট)
#
#                B1_family_type B2_family_time_hours B3_family_relationship  \
# 0  Single family(একক পরিবার )                    3            Good (ভালো)
# 1   Joint Family (যৌথ পরিবার)           10 min max  Very Good (খুবই ভালো)
# 2  Single family(একক পরিবার )                  5/6  Very Good (খুবই ভালো)
# 3   Joint Family (যৌথ পরিবার)            2/3 Hours      Moderate (মাঝারি)
# 4  Single family(একক পরিবার )                    0            Good (ভালো)
#
#                                 B4_in_person_feeling  ...  \
# 0  Somewhat Comfortable (কিছুটা স্বাচ্ছন্দ্যবোধ করি)  ...
# 1                                 Neutral (নিরপেক্ষ)  ...
# 2  Somewhat Comfortable (কিছুটা স্বাচ্ছন্দ্যবোধ করি)  ...
# 3         Very Comfortable (খুব স্বাচ্ছন্দ্যবোধ করি)  ...
# 4                                 Neutral (নিরপেক্ষ)  ...
#
#         G6_panic_attacks        G7_behavior_type  G8_addictive_watching  \
# 0  Sometimes (মাঝে মাঝে)   Extrovert (বহির্মুখী)  Sometimes (মাঝে মাঝে)
# 1        Never (কখনো না)  Introvert (অন্তর্মুখী)        Never (কখনো না)
# 2  Sometimes (মাঝে মাঝে)  Introvert (অন্তর্মুখী)        Always (সবসময়)
# 3        Never (কখনো না)     Ambivert (মাঝামাঝি)  Sometimes (মাঝে মাঝে)
# 4  Sometimes (মাঝে মাঝে)     Ambivert (মাঝামাঝি)        Always (সবসময়)
#
#              H1_mental_state_change             H2_content_type_effect  \
# 0  Some Change (কিছুটা পরিবর্তন হয়)  Negative Impact (নেতিবাচক প্রভাব)
# 1          No Change (পরিবর্তন নেই)     No Impact (কোনো প্রভাব পড়ে না)
# 2  Some Change (কিছুটা পরিবর্তন হয়)              Not Sure (নিশ্চিত না)
# 3  Some Change (কিছুটা পরিবর্তন হয়)              Not Sure (নিশ্চিত না)
# 4  Some Change (কিছুটা পরিবর্তন হয়)              Not Sure (নিশ্চিত না)
#
#   H3_distraction_after_viral                      H4_brain_pressure  \
# 0      Sometimes (মাঝে মাঝে)  Moderate Stress (মাঝারি চাপ অনুভব হয়)
# 1            Never (কখনো না)            No Stress (চাপ অনুভব হয় না)
# 2      Sometimes (মাঝে মাঝে)            No Stress (চাপ অনুভব হয় না)
# 3            Never (কখনো না)            No Stress (চাপ অনুভব হয় না)
# 4            Rarely (খুব কম)      Low Stress (সামান্য চাপ অনুভব হয়)
#
#                              H5_sleep_quality_change  \
# 0  Slight Change in Sleep Quality (ঘুমের মান কিছু...
# 1                              Not Sure (নিশ্চিত না)
# 2                              Not Sure (নিশ্চিত না)
# 3                              Not Sure (নিশ্চিত না)
# 4  Slight Change in Sleep Quality (ঘুমের মান কিছু...
#
#                    H6_emotional_reels_focus_loss  \
# 0   Lose Focus Frequently (অত্যধিক মনোযোগ হারায়)
# 1              Do Not Lose Focus (মনোযোগ কমে না)
# 2  Lose Focus Sometimes (মাঝে মাঝে মনোযোগ হারায়)
# 3              Do Not Lose Focus (মনোযোগ কমে না)
# 4        Lose Focus Rarely (খুব কম মনোযোগ হারায়)
#
#                          H7_curiosity_driven_rewatch
# 0          Sometimes Interested (মাঝে মাঝে আগ্রহ হয়)
# 1                Rarely Interested (খুব কম আগ্রহ হয়)
# 2  More Interest in Watching Reels (আরও রিলস দেখা...
# 3          Sometimes Interested (মাঝে মাঝে আগ্রহ হয়)
# 4          Sometimes Interested (মাঝে মাঝে আগ্রহ হয়)
#
# [5 rows x 41 columns]

# %%
# Remove Bangla text, keeping only the English part of each value
# Values look like "English text (বাংলা text)" -> keep "English text"
bangla_pattern = re.compile(r"\s*\([^()]*[ঀ-৿][^()]*\)")


def strip_bangla(value):
    if isinstance(value, str):
        cleaned = bangla_pattern.sub("", value)
        cleaned = re.sub(r"[ঀ-৿]+", "", cleaned)
        return cleaned.strip()
    return value


df = df.apply(lambda col: col.map(strip_bangla))
df.head()
# Out:
#   A1_age A2_gender A3_religion A4_marital_status A5_residence   A6_occupation  \
# 0     24      Male       Islam           Married   Urban Area         Student
# 1     28      Male       Islam         Unmarried   Urban Area  Service Holder
# 2     25    Female       Islam         Unmarried   Urban Area         Student
# 3     25      Male       Islam           Married   Urban Area         Student
# 4     25    Female       Islam         Unmarried   Urban Area         Student
#
#   B1_family_type B2_family_time_hours B3_family_relationship  \
# 0  Single family                    3                   Good
# 1   Joint Family           10 min max              Very Good
# 2  Single family                  5/6              Very Good
# 3   Joint Family            2/3 Hours               Moderate
# 4  Single family                    0                   Good
#
#    B4_in_person_feeling  ... G6_panic_attacks G7_behavior_type  \
# 0  Somewhat Comfortable  ...        Sometimes        Extrovert
# 1               Neutral  ...            Never        Introvert
# 2  Somewhat Comfortable  ...        Sometimes        Introvert
# 3      Very Comfortable  ...            Never         Ambivert
# 4               Neutral  ...        Sometimes         Ambivert
#
#   G8_addictive_watching H1_mental_state_change H2_content_type_effect  \
# 0             Sometimes            Some Change        Negative Impact
# 1                 Never              No Change              No Impact
# 2                Always            Some Change               Not Sure
# 3             Sometimes            Some Change               Not Sure
# 4                Always            Some Change               Not Sure
#
#   H3_distraction_after_viral H4_brain_pressure  \
# 0                  Sometimes   Moderate Stress
# 1                      Never         No Stress
# 2                  Sometimes         No Stress
# 3                      Never         No Stress
# 4                     Rarely        Low Stress
#
#           H5_sleep_quality_change H6_emotional_reels_focus_loss  \
# 0  Slight Change in Sleep Quality         Lose Focus Frequently
# 1                        Not Sure             Do Not Lose Focus
# 2                        Not Sure          Lose Focus Sometimes
# 3                        Not Sure             Do Not Lose Focus
# 4  Slight Change in Sleep Quality             Lose Focus Rarely
#
#        H7_curiosity_driven_rewatch
# 0             Sometimes Interested
# 1                Rarely Interested
# 2  More Interest in Watching Reels
# 3             Sometimes Interested
# 4             Sometimes Interested
#
# [5 rows x 41 columns]

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="Reels & Mental Health Survey - Full Dataset Profile",
    explorative=True,
)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 41/41 [00:00<00:00, 171.23it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-09-25 17:17:24.693061&quot; name=date&gt;&lt;title&gt;Reels &amp; Mental Health Survey - Full Dataset Profile&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
# Show all unique values (with counts) for every column as an HTML report
from html import escape
from IPython.display import HTML, display


def describe_value(value):
    """Return (label, css_class) so missing / blank / junk values stand out."""
    if pd.isna(value):
        return "NaN (missing)", "missing"
    text = str(value)
    if text.strip() == "":
        return f"'{text}' (blank)", "missing"
    if not re.search(r"[A-Za-z0-9]", text):
        return f"'{text}' (no letters/digits)", "junk"
    return text, ""


sections = []
for col in df.columns:
    counts = df[col].value_counts(dropna=False)
    n_missing = int(df[col].isna().sum() + (df[col].astype(str).str.strip() == "").sum())
    rows = "".join(
        f"<tr class='{cls}'><td>{escape(label)}</td><td class='num'>{count}</td></tr>"
        for label, cls, count in (
            (*describe_value(value), count) for value, count in counts.items()
        )
    )
    sections.append(
        f"<details {'open' if len(counts) <= 10 else ''}>"
        f"<summary><b>{escape(col)}</b> &mdash; {len(counts)} unique, "
        f"{n_missing} missing/blank</summary>"
        f"<table><tr><th>Value</th><th>Count</th></tr>{rows}</table></details>"
    )

style = """
<style>
.uv details { margin: 6px 0; border: 1px solid #8884; border-radius: 6px; padding: 6px 10px; }
.uv summary { cursor: pointer; }
.uv table { border-collapse: collapse; margin-top: 6px; min-width: 360px; }
.uv th, .uv td { border: 1px solid #8884; padding: 3px 8px; text-align: left; white-space: pre-wrap; }
.uv td.num { text-align: right; width: 60px; }
.uv tr.missing td { background: #e5484d33; }
.uv tr.junk td { background: #f5a52433; }
</style>
"""
display(HTML(
    style
    + f"<div class='uv'><p>{len(df)} rows &times; {len(df.columns)} columns. "
    "Red = missing/blank, orange = no letters/digits. "
    "Columns with more than 10 values are collapsed &mdash; click to expand.</p>"
    + "".join(sections)
    + "</div>"
))
# Out:
# <style>
# .uv details { margin: 6px 0; border: 1px solid #8884; border-radius: 6px; padding: 6px 10px; }
# .uv summary { cursor: pointer; }
# .uv table { border-collapse: collapse; margin-top: 6px; min-width: 360px; }
# .uv th, .uv td { border: 1px solid #8884; padding: 3px 8px; text-align: left; white-space: pre-wrap; }
# .uv td.num { text-align: right; width: 60px; }
# .uv tr.missing td { background: #e5484d33; }
# .uv tr.junk td { background: #f5a52433; }
# </style>
# <div class='uv'><p>506 rows &times; 41 columns. Red = missing/blank, orange = no letters/digits. Columns with more than 10 values are collapsed &mdash; click to expand.</p><details ><summary><b>A1_age</b> &mdash; 28 unique, 4 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>25</td><td class='num'>69</td></tr><tr class=''><td>24</td><td class='num'>66</td></tr><tr class=''><td>22</td><td class='num'>58</td></tr><tr class=''><td>23</td><td class='num'>56</td></tr><tr class=''><td>21</td><td class='num'>47</td></tr><tr class=''><td>20</td><td class='num'>37</td></tr><tr class=''><td>26</td><td class='num'>23</td></tr><tr class=''><td>33</td><td class='num'>19</td></tr><tr class=''><td>28</td><td class='num'>18</td></tr><tr class=''><td>32</td><td class='num'>17</td></tr><tr class=''><td>30</td><td class='num'>16</td></tr><tr class=''><td>35</td><td class='num'>16</td></tr><tr class=''><td>27</td><td class='num'>16</td></tr><tr class=''><td>31</td><td class='num'>12</td></tr><tr class=''><td>34</td><td class='num'>11</td></tr><tr class=''><td>29</td><td class='num'>10</td></tr><tr class='missing'><td>NaN (missing)</td><td class='num'>3</td></tr><tr class=''><td>18</td><td class='num'>2</td></tr><tr class=''><td>Ratul Halder</td><td class='num'>1</td></tr><tr class='missing'><td>&#x27;&#x27; (blank)</td><td class='num'>1</td></tr><tr class=''><td>17</td><td class='num'>1</td></tr><tr class=''><td>25 years</td><td class='num'>1</td></tr><tr class=''><td>16</td><td class='num'>1</td></tr><tr class=''><td>20 year 8.5 month</td><td class='num'>1</td></tr><tr class=''><td>24 years</td><td class='num'>1</td></tr><tr class=''><td>22 years</td><td class='num'>1</td></tr><tr class=''><td>25years</td><td class='num'>1</td></tr><tr class=''><td>27 year</td><td class='num'>1</td></tr></table></details><details open><summary><b>A2_gender</b> &mdash; 3 unique, 2 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>Male</td><td class='num'>335</td></tr><tr class=''><td>Female</td><td class='num'>169</td></tr><tr class='missing'><td>NaN (missing)</td><td class='num'>2</td></tr></table></details><details open><summary><b>A3_religion</b> &mdash; 4 unique, 3 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>Islam</td><td class='num'>488</td></tr><tr class=''><td>Hindu</td><td class='num'>12</td></tr><tr class='missing'><td>NaN (missing)</td><td class='num'>3</td></tr><tr class=''><td>Christian</td><td class='num'>3</td></tr></table></details><details open><summary><b>A4_marital_status</b> &mdash; 4 unique, 2 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>Unmarried</td><td class='num'>325</td></tr><tr class=''><td>Married</td><td class='num'>174</td></tr><tr class=''><td>Divorced</td><td class='num'>5</td></tr><tr class='missing'><td>NaN (missing)</td><td class='num'>2</td></tr></table></details><details open><summary><b>A5_residence</b> &mdash; 3 unique, 3 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>Urban Area</td><td class='num'>293</td></tr><tr class=''><td>Rural Area</td><td class='num'>210</td></tr><tr class='missing'><td>NaN (missing)</td><td class='num'>3</td></tr></table></details><details open><summary><b>A6_occupation</b> &mdash; 5 unique, 3 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>Student</td><td class='num'>316</td></tr><tr class=''><td>Service Holder</td><td class='num'>73</td></tr><tr class=''><td>Others</td><td class='num'>70</td></tr><tr class=''><td>Businessperson</td><td class='num'>44</td></tr><tr class='missing'><td>NaN (missing)</td><td class='num'>3</td></tr></table></details><details open><summary><b>B1_family_type</b> &mdash; 5 unique, 2 missing/blank</summary><table><tr><th>Value</th><th>Count</th></tr><tr class=''><td>Single family</td><td class='num'>311</td></tr><tr class=''><td>Joint Family</td><td class='n ...
