# %%
import pandas as pd
df = pd.read_csv("dataset/dataset_v1.csv")
df.head()
# Out:
#   A1_age A2_gender A3_religion A4_marital_status A5_residence   A6_occupation  \
# 0     24      Male       Islam           Married   Urban Area         Student
# 1     28      Male       Islam         Unmarried   Urban Area  Service Holder
# 2     25    Female       Islam         Unmarried   Urban Area         Student
# 3     25      Male       Islam           Married   Urban Area         Student
# 4     25    Female       Islam         Unmarried   Urban Area         Student
#
#   B1_family_type B2_family_time_hours B3_family_relationship  \
# 0  Single family                    3                   Good
# 1   Joint Family           10 min max              Very Good
# 2  Single family                  5/6              Very Good
# 3   Joint Family            2/3 Hours               Moderate
# 4  Single family                    0                   Good
#
#    B4_in_person_feeling  ... G6_panic_attacks G7_behavior_type  \
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="Reels & Mental Health Survey - Full Dataset Profile",
    explorative=True,
)
profile.to_notebook_iframe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# Show all raw values / value counts for B2_family_time_hours
pd.set_option('display.max_rows', None)
df['B2_family_time_hours'].value_counts(dropna=False)
# Out:
# B2_family_time_hours
# 2                                                           67
# 6                                                           49
# 1                                                           37
# 5                                                           35
# 3                                                           34
# 7                                                           29
# 4                                                           27
# 8                                                           23
# 10                                                          23
# 0                                                           20
# 12                                                          17
# NaN                                                         10
# 24                                                           8
# 14                                                           7
# 16                                                           5
# ...

# %%
# Show all unique values for B2_family_time_hours
df['B2_family_time_hours'].unique()
# Out:
# array(['3', '10 min max', '5/6', '2/3 Hours', '0',
#        '4/5 hours or whole day', '4', '2', '3-4', '12', '18', '1',
#        '8 hours', '0 because i live alone at dhaka city', '3 to 6 hour',
#        ',', '1-2', 'Less than 10 minutes', '19-20', '5', '12-15', '5/6hr',
#        '6', '5 hours', '10', '16 Hours', nan, '6 hours', '2/3 hours',
#        '15 hours', '3/4 hours', 'Full time', '8-10', '24', '2-3', '16',
#        '2 hours', '8hour', 'More than 5-6 hour', '22', '4 hours', '2h',
#        '8', '5hours', ',         ।', '14 hour', 'More then 10 hours',
#        '18 hours', '5hr', '14', '10/12', "Average 2 hour's", '1 hour',
#        '4to 5 hours depends', '30m', '1/2 hour', '30', '16 hours', '-',
#        '4h', '4 hour', '।', 'Less than 1 hour', '6/7 hours', '5-6',
#        '12 hours', '2hrs', '5-6h', '1 hours', '5h',
#        '20 to 30 minutes...Ami mess ee thaki just phne Kotha hoi',
#        '0 hour', '4 h', '8-7 hr', '4-5', '3-5 hours', '17-18 hours',
# ...
